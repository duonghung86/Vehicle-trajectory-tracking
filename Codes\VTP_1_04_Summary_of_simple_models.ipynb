# %% [markdown]
# <a href="https://colab.research.google.com/github/duonghung86/Vehicle-trajectory-tracking/blob/master/Codes%5CVTP_1_04_Summary_of_simple_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # All step-by-step LSTM models for vehicle trajectory prediction
# ---

# %% [markdown]
# <img src="data:image/png;base64,..." style="cursor:pointer;max-width:100%;" onclick="(function(img){if(img.wnd!=null&&!img.wnd.closed){img.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&&evt.source==img.wnd){img.wnd.postMessage(decodeURIComponent(img.getAttribute('src')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);img.wnd=window.open('https://viewer.diagrams.net/?client=1&edit=_blank');}})(this);"/>

# %% [markdown]
# Overview on the configuration of all simple models
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 1|Baseline model with multi input time steps|1|1|1|0|**4**|1|
# Model 2|Add multi output time steps|1|1|1|0|4|**2**|
# Model 3|Add multi input series|1|**2**|1|0|4|2|
# Model 4|Add multi `output` series|1|2|**2**|0|4|2|
# Model 5|Add multi constant input|1|2|2|**2**|4|2|
# Model 6|Add more objects|**4**|2|2|2|4|2|

# %% [markdown]
# ## Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

plt.rcParams['figure.figsize'] = (8, 6)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Load dataset

# %%
url_1 = 'https://github.com/duonghung86/Vehicle-trajectory-tracking/raw/master/Data/NGSIM/0750_0805_us101_smoothed_11_.zip'
zip_path = tf.keras.utils.get_file(origin=url_1, fname=url_1.split('/')[-1], extract=True)
csv_path = zip_path.replace('zip','csv')
csv_path
# Out:
# Downloading data from https://github.com/duonghung86/Vehicle-trajectory-tracking/raw/master/Data/NGSIM/0750_0805_us101_smoothed_11_.zip
# 59645952/59637793 [==============================] - 1s 0us/step
# '/root/.keras/datasets/0750_0805_us101_smoothed_11_.csv'

# %% [markdown]
# Let's take a glance at the data. Here are the first few rows:

# %%
df = pd.read_csv(csv_path)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Vehicle_ID    1048575 non-null  int64
#  1   Frame_ID      1048575 non-null  int64
#  2   Total_Frames  1048575 non-null  int64
#  3   Global_Time   1048575 non-null  int64
#  4   Local_X       1048575 non-null  float64
#  5   Local_Y       1048575 non-null  float64
#  6   Global_X      1048575 non-null  float64
#  7   Global_Y      1048575 non-null  float64
#  8   v_Length      1048575 non-null  float64
#  9   v_Width       1048575 non-null  float64
#  10  v_Class       1048575 non-null  int64
#  11  v_Vel         1048575 non-null  float64
#  12  v_Acc         1048575 non-null  float64
#  13  Lane_ID       1048575 non-null  int64
#  14  Preceeding    1048575 non-null  int64
#  15  Following     1048575 non-null  int64
#  16  Space_Hdwy    1048575 non-null  float64
#  17  Time_Hdwy     1048575 non-null  float64
# dtypes: float64(10), int64(8)
# memory usage: 144.0 MB
#    Vehicle_ID  Frame_ID  Total_Frames  ...  Following  Space_Hdwy  Time_Hdwy
# 0           2        13           437  ...          0         0.0        0.0
# 1           2        14           437  ...          0         0.0        0.0
# 2           2        15           437  ...          0         0.0        0.0
# 3           2        16           437  ...          0         0.0        0.0
# 4           2        17           437  ...          0         0.0        0.0
#
# [5 rows x 18 columns]

# %% [markdown]
# Next look at the statistics of the dataset:

# %%
df.describe().transpose().round(3)
# Out:
#                   count          mean  ...           75%           max
# Vehicle_ID    1048575.0  1.533080e+03  ...  2.210000e+03  2.783000e+03
# Frame_ID      1048575.0  4.518249e+03  ...  6.598000e+03  8.906000e+03
# Total_Frames  1048575.0  5.608770e+02  ...  6.400000e+02  1.010000e+03
# Global_Time   1048575.0  1.118847e+12  ...  1.118848e+12  1.118848e+12
# Local_X       1048575.0  2.940600e+01  ...  4.187500e+01  7.347800e+01
# Local_Y       1048575.0  1.002056e+03  ...  1.491548e+03  2.195470e+03
# Global_X      1048575.0  6.451838e+06  ...  6.452205e+06  6.452734e+06
# Global_Y      1048575.0  1.872677e+06  ...  1.873015e+06  1.873365e+06
# v_Length      1048575.0  1.463500e+01  ...  1.650000e+01  7.610000e+01
# v_Width       1048575.0  6.132000e+00  ...  6.900000e+00  8.500000e+00
# v_Class       1048575.0  2.009000e+00  ...  2.000000e+00  3.000000e+00
# v_Vel         1048575.0  3.877400e+01  ...  4.820200e+01  1.490520e+02
# v_Acc         1048575.0  3.610000e-01  ...  2.754000e+00  2.430030e+02
# Lane_ID       1048575.0  2.956000e+00  ...  4.000000e+00  8.000000e+00
# Preceeding    1048575.0  1.459864e+03  ...  2.186000e+03  3.109000e+03
# Following     1048575.0  1.477269e+03  ...  2.202000e+03  3.109000e+03
# Space_Hdwy    1048575.0  7.815800e+01  ...  9.725000e+01  7.777300e+02
# Time_Hdwy     1048575.0  1.090800e+02  ...  2.730000e+00  9.999990e+03
#
# [18 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Vehicle_ID', 'Frame_ID', 'Total_Frames', 'Global_Time', 'Local_X',
#        'Local_Y', 'Global_X', 'Global_Y', 'v_Length', 'v_Width', 'v_Class',
#        'v_Vel', 'v_Acc', 'Lane_ID', 'Preceeding', 'Following', 'Space_Hdwy',
#        'Time_Hdwy'],
#       dtype='object')

# %%
#  keep only columns that are useful for now
kept_cols = ['Vehicle_ID', 'Frame_ID', 'Total_Frames', 'Local_X','Local_Y','v_Length', 'v_Width', 'v_Class',
       'v_Vel', 'v_Acc', 'Lane_ID']
df = df[kept_cols]
df.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames  ...      v_Vel     v_Acc  Lane_ID
# 0           2        13           437  ...  40.000000  0.000000        2
# 1           2        14           437  ...  40.012349  0.123485        2
# 2           2        15           437  ...  39.999855 -0.124939        2
# 3           2        16           437  ...  39.992920 -0.069349        2
# 4           2        17           437  ...  39.991544 -0.013759        2
#
# [5 rows x 11 columns]

# %%
'the number of vehicles is {}'.format(len(df.Vehicle_ID.unique()))
# Out:
# 'the number of vehicles is 1993'

# %% [markdown]
# # Model 1
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 1|Baseline model with multi input time steps|1|1|1|0|**4**|1|

# %% [markdown]
# ## Data preparation

# %%
# Let pick the vehicle that had longest historical data
max_frames = df.Total_Frames.max()
print(max_frames)
car_id = df[df.Total_Frames==max_frames].Vehicle_ID.unique()
"ID of the car that have longest data is {} ".format(car_id[0])
# Out:
# 1010
# 'ID of the car that have longest data is 2582 '

# %%
simple_df = df[df.Vehicle_ID==car_id[0]].copy()
simple_df.head()
# Out:
#         Vehicle_ID  Frame_ID  Total_Frames  ...      v_Vel     v_Acc  Lane_ID
# 932102        2582      7263          1010  ...  45.030000  0.000000        1
# 932103        2582      7264          1010  ...  44.490366 -5.396343        1
# 932104        2582      7265          1010  ...  44.918464  4.280980        1
# 932105        2582      7266          1010  ...  45.187921  2.694570        1
# 932106        2582      7267          1010  ...  45.298705  1.107846        1
#
# [5 rows x 11 columns]

# %% [markdown]
# ### series2seq1: Function that return sequence input and output| Version 1
#
# **Arguments**:
#
# - data: Sequence of observations as a list or NumPy array.
# - n_in: Number of lag observations as input (X).
# - n_out: Number of observations as output (y).
# - dropnan: Boolean whether or not to drop rows with NaN values.
#
# **Returns**:
# - X: Feature Pandas DataFrame
# - y: Label Pandas dataframe

# %%
def series2seq1(data, n_in=1, n_out=1, dropnan=True):

    dat = data.copy()

    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(dat.shift(i))
        names += ['{}(t-{})'.format(dat.name, i) ]

    # forecast sequence (t, t+1, ... t+n) for selected labels
    for i in range(0, n_out):
        cols.append(dat.shift(-i))
        if i == 0:
            names += ['{}(t)'.format(dat.name)]
        else:
            names += ['{}(t+{})'.format(dat.name, i)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    X = agg.iloc[:,:n_in]
    y = agg.iloc[:,n_in:].copy()
    return X, y
  
# Test the function
X, y = series2seq1(df.Local_X, n_in=2, n_out=1, dropnan=False)
print(X.head())
print(y.head())
# Out:
#    Local_X(t-2)  Local_X(t-1)
# 0           NaN           NaN
# 1           NaN     16.467196
# 2     16.467196     16.446594
# 3     16.446594     16.425991
# 4     16.425991     16.405392
#    Local_X(t)
# 0   16.467196
# 1   16.446594
# 2   16.425991
# 3   16.405392
# 4   16.384804

# %%
n_steps = 4
n_labels = 1
n_future = 1
n_features = 1

# %%
X, y = series2seq1(simple_df.Local_X, n_in=n_steps, n_out=n_future, dropnan=True)
print(X.head(), X.shape)
print(y.head(), y.shape)
# Out:
#         Local_X(t-4)  Local_X(t-3)  Local_X(t-2)  Local_X(t-1)
# 932106      4.725434      4.694650      4.668727      4.646575
# 932107      4.694650      4.668727      4.646575      4.627103
# 932108      4.668727      4.646575      4.627103      4.609221
# 932109      4.646575      4.627103      4.609221      4.591890
# 932110      4.627103      4.609221      4.591890      4.571389 (1006, 4)
#         Local_X(t)
# 932106    4.627103
# 932107    4.609221
# 932108    4.591890
# 932109    4.571389
# 932110    4.543895 (1006, 1)

# %% [markdown]
# ### Split the data set

# %%
### Split the data set
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)
# Out:
# (704, 4) (302, 4) (704, 1) (302, 1)

# %%
### Standardize the data
train_mean = X_train.mean()
train_std = X_train.std()

X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print(X_train.shape)
X_train.describe()
# Out:
# (704, 4)
#        Local_X(t-4)  Local_X(t-3)  Local_X(t-2)  Local_X(t-1)
# count  7.040000e+02  7.040000e+02  7.040000e+02  7.040000e+02
# mean  -2.775558e-17 -1.196328e-15  3.258126e-16  8.500145e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.576153e+00 -1.579742e+00 -1.581828e+00 -1.586446e+00
# 25%   -1.066901e+00 -1.068516e+00 -1.072927e+00 -1.078394e+00
# 50%    4.124348e-01  4.110169e-01  4.097522e-01  4.082909e-01
# 75%    9.612696e-01  9.611536e-01  9.600897e-01  9.587113e-01
# max    1.266498e+00  1.266102e+00  1.265693e+00  1.265163e+00

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')


# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 0s 16ms/step - loss: 221.3227 - mse: 221.3227 - val_loss: 212.5289 - val_mse: 212.5289
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 214.4205 - mse: 214.4205 - val_loss: 204.2162 - val_mse: 204.2162
# Epoch 3/100
# 22/22 [==============================] - 0s 4ms/step - loss: 201.4982 - mse: 201.4982 - val_loss: 181.5976 - val_mse: 181.5976
# Epoch 4/100
# 22/22 [==============================] - 0s 4ms/step - loss: 151.3691 - mse: 151.3691 - val_loss: 80.7729 - val_mse: 80.7729
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 30.8123 - mse: 30.8123 - val_loss: 11.1319 - val_mse: 11.1319
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 9.8225 - mse: 9.8225 - val_loss: 7.2499 - val_mse: 7.2499
# Epoch 7/100
# 22/22 [==============================] - 0s 4ms/step - loss: 6.6018 - mse: 6.6018 - val_loss: 5.2032 - val_mse: 5.2032
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 4.7111 - mse: 4.7111 - val_loss: 3.9354 - val_mse: 3.9354
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 3.5026 - mse: 3.5026 - val_loss: 2.9508 - val_mse: 2.9508
# Epoch 10/100
# 22/22 [==============================] - 0s 4ms/step - loss: 2.6859 - mse: 2.6859 - val_loss: 2.3326 - val_mse: 2.3326
# Epoch 11/100
# 22/22 [==============================] - 0s 5ms/step - loss: 2.1405 - mse: 2.1405 - val_loss: 1.9249 - val_mse: 1.9249
# Epoch 12/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.7480 - mse: 1.7480 - val_loss: 1.6044 - val_mse: 1.6044
# Epoch 13/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.4692 - mse: 1.4692 - val_loss: 1.3757 - val_mse: 1.3757
# Epoch 14/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.2269 - mse: 1.2269 - val_loss: 1.1288 - val_mse: 1.1288
# Epoch 15/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0161 - mse: 1.0161 - val_loss: 0.9627 - val_mse: 0.9627
# Epoch 16/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8446 - mse: 0.8446 - val_loss: 0.7879 - val_mse: 0.7879
# Epoch 17/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6977 - mse: 0.6977 - val_loss: 0.6871 - val_mse: 0.6871
# Epoch 18/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5658 - mse: 0.5658 - val_loss: 0.5148 - val_mse: 0.5148
# Epoch 19/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4368 - mse: 0.4368 - val_loss: 0.4178 - val_mse: 0.4178
# Epoch 20/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3437 - mse: 0.3437 - val_loss: 0.3385 - val_mse: 0.3385
# Epoch 21/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2769 - mse: 0.2769 - val_loss: 0.2533 - val_mse: 0.2533
# Epoch 22/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2179 - mse: 0.2179 - val_loss: 0.2048 - val_mse: 0.2048
# Epoch 23/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1817 - mse: 0.1817 - val_loss: 0.1658 - val_mse: 0.1658
# Epoch 24/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1512 - mse: 0.1512 - val_loss: 0.1359 - val_mse: 0.1359
# Epoch 25/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1240 - mse: 0.1240 - val_loss: 0.1137 - val_mse: 0.1137
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1102 - mse: 0.1102 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 27/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0998 - mse: 0.0998 - val_loss: 0.0967 - val_mse: 0.0967
# Epoch 28/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0877 - val_mse: 0.0877
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0910 - mse: 0.0910 - val_loss: 0.0892 - val_mse: 0.0892
# Epoch 30/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0894 - mse: 0.0894 - val_loss: 0.0908 - val_mse: 0.0908
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0890 - mse: 0.0890 - val_loss: 0.0892 - val_mse: 0.0892
# Epoch 32/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0882 - mse: 0.0882 - val_loss: 0.0844 - val_mse: 0.0844
# Epoch 33/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0892 - mse: 0.0892 - val_loss: 0.0887 - val_mse: 0.0887
# Epoch 34/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0888 - mse: 0.0888 - val_loss: 0.0870 - val_mse: 0.0870
# Epoch 35/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0871 - mse: 0.0871 - val_loss: 0.0915 - val_mse: 0.0915
# Epoch 36/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0866 - mse: 0.0866 - val_loss: 0.0858 - val_mse: 0.0858
# Epoch 37/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0898 - mse: 0.0898 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 38/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0860 - mse: 0.0860 - val_loss: 0.0815 - val_mse: 0.0815
# Epoch 39/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0873 - mse: 0.0873 - val_loss: 0.0838 - val_mse: 0.0838
# Epoch 40/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0887 - mse: 0.0887 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 41/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0833 - val_mse: 0.0833
# Epoch 42/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0847 - mse: 0.0847 - val_loss: 0.0817 - val_mse: 0.0817
# Epoch 43/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0864 - mse: 0.0864 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 44/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0872 - mse: 0.0872 - val_loss: 0.0848 - val_mse: 0.0848
# Epoch 45/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0819 - val_mse: 0.0819
# Epoch 46/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0863 - mse: 0.0863 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 47/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0906 - mse: 0.0906 - val_loss: 0.0912 - val_mse: 0.0912
# Epoch 48/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0874 - mse: 0.0874 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 49/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0846 - mse: 0.0846 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 50/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0917 - mse: 0.0917 - val_loss: 0.0834 - val_mse: 0.0834
# Epoch 51/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0857 - mse: 0.0857 - val_loss: 0.0822 - val_mse: 0.0822
# Epoch 52/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0862 - mse: 0.0862 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 53/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0907 - mse: 0.0907 - val_loss: 0.0915 - val_mse: 0.0915
# Epoch 54/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0867 - mse: 0.0867 - val_loss: 0.0854 - val_mse: 0.0854
# Epoch 55/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0827 - val_mse: 0.0827
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.1012 - val_mse: 0.1012

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()
# Out:
#         loss       mse  val_loss   val_mse  epoch
# 51  0.086188  0.086188  0.080987  0.080987     51
# 52  0.090711  0.090711  0.091527  0.091527     52
# 53  0.086731  0.086731  0.085422  0.085422     53
# 54  0.086913  0.086913  0.082686  0.082686     54
# 55  0.087510  0.087510  0.101190  0.101190     55

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
yhat = model.predict(X_test, verbose=1)
rms = [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms
# Out:
# 10/10 [==============================] - 0s 1ms/step
# [[21.001719]
#  [16.715609]
#  [16.378654]
#  [19.681747]
#  [ 7.991546]]
# [0.31810299249074997]

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test.index,y_test, label = "true Local_X at t",marker = 'X', )
plt.scatter(y_test.index,yhat, label = "prediction Local_X at t",marker = '.')
plt.legend()
plt.show()

# %% [markdown]
# # Model 2
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 2|Add multi output time steps|1|1|1|0|4|**2**|

# %% [markdown]
# ## Data preparation
#
# We will use the same data set as model 1

# %%
n_steps = 4
n_labels = 1
n_future = 2
n_features = 1

# %%
X, y = series2seq1(simple_df.Local_X, n_in=n_steps, n_out=n_future, dropnan=True)
print(X.head(), X.shape)
print(y.head(), y.shape)
# Out:
#         Local_X(t-4)  Local_X(t-3)  Local_X(t-2)  Local_X(t-1)
# 932106      4.725434      4.694650      4.668727      4.646575
# 932107      4.694650      4.668727      4.646575      4.627103
# 932108      4.668727      4.646575      4.627103      4.609221
# 932109      4.646575      4.627103      4.609221      4.591890
# 932110      4.627103      4.609221      4.591890      4.571389 (1005, 4)
#         Local_X(t)  Local_X(t+1)
# 932106    4.627103      4.609221
# 932107    4.609221      4.591890
# 932108    4.591890      4.571389
# 932109    4.571389      4.543895
# 932110    4.543895      4.515965 (1005, 2)

# %% [markdown]
# ### Split the data set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)
# Out:
# (703, 4) (302, 4) (703, 2) (302, 2)

# %%
### Standardize the data
train_mean = X_train.mean()
train_std = X_train.std()

X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print(X_train.shape)
X_train.describe()
# Out:
# (703, 4)
#        Local_X(t-4)  Local_X(t-3)  Local_X(t-2)  Local_X(t-1)
# count  7.030000e+02  7.030000e+02  7.030000e+02  7.030000e+02
# mean  -3.787077e-16 -1.895118e-17  2.337312e-17  7.615214e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.575110e+00 -1.578736e+00 -1.580849e+00 -1.585490e+00
# 25%   -1.067267e+00 -1.067488e+00 -1.073312e+00 -1.077957e+00
# 50%    4.144181e-01  4.130314e-01  4.118561e-01  4.104574e-01
# 75%    9.633450e-01  9.625659e-01  9.618094e-01  9.610258e-01
# max    1.268899e+00  1.268625e+00  1.268315e+00  1.267863e+00

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')


# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 0s 14ms/step - loss: 219.5254 - mse: 219.5254 - val_loss: 212.3854 - val_mse: 212.3854
# Epoch 2/100
# 22/22 [==============================] - 0s 5ms/step - loss: 213.2573 - mse: 213.2573 - val_loss: 203.0655 - val_mse: 203.0655
# Epoch 3/100
# 22/22 [==============================] - 0s 5ms/step - loss: 193.3549 - mse: 193.3549 - val_loss: 162.3588 - val_mse: 162.3588
# Epoch 4/100
# 22/22 [==============================] - 0s 5ms/step - loss: 97.7350 - mse: 97.7350 - val_loss: 39.9566 - val_mse: 39.9566
# Epoch 5/100
# 22/22 [==============================] - 0s 5ms/step - loss: 33.0723 - mse: 33.0723 - val_loss: 20.9677 - val_mse: 20.9677
# Epoch 6/100
# 22/22 [==============================] - 0s 5ms/step - loss: 12.8090 - mse: 12.8090 - val_loss: 8.8973 - val_mse: 8.8973
# Epoch 7/100
# 22/22 [==============================] - 0s 5ms/step - loss: 7.5265 - mse: 7.5265 - val_loss: 5.5191 - val_mse: 5.5191
# Epoch 8/100
# 22/22 [==============================] - 0s 5ms/step - loss: 4.5308 - mse: 4.5308 - val_loss: 3.4911 - val_mse: 3.4911
# Epoch 9/100
# 22/22 [==============================] - 0s 5ms/step - loss: 2.9465 - mse: 2.9465 - val_loss: 2.4682 - val_mse: 2.4682
# Epoch 10/100
# 22/22 [==============================] - 0s 5ms/step - loss: 2.0807 - mse: 2.0807 - val_loss: 1.8088 - val_mse: 1.8088
# Epoch 11/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.5908 - mse: 1.5908 - val_loss: 1.4181 - val_mse: 1.4181
# Epoch 12/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.2039 - mse: 1.2039 - val_loss: 1.0568 - val_mse: 1.0568
# Epoch 13/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8806 - mse: 0.8806 - val_loss: 0.7768 - val_mse: 0.7768
# Epoch 14/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6243 - mse: 0.6243 - val_loss: 0.5568 - val_mse: 0.5568
# Epoch 15/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4842 - mse: 0.4842 - val_loss: 0.4716 - val_mse: 0.4716
# Epoch 16/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4213 - mse: 0.4213 - val_loss: 0.4163 - val_mse: 0.4163
# Epoch 17/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3741 - mse: 0.3741 - val_loss: 0.3821 - val_mse: 0.3821
# Epoch 18/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3480 - mse: 0.3480 - val_loss: 0.3558 - val_mse: 0.3558
# Epoch 19/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3160 - mse: 0.3160 - val_loss: 0.3135 - val_mse: 0.3135
# Epoch 20/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2898 - mse: 0.2898 - val_loss: 0.3053 - val_mse: 0.3053
# Epoch 21/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2766 - mse: 0.2766 - val_loss: 0.2816 - val_mse: 0.2816
# Epoch 22/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2580 - mse: 0.2580 - val_loss: 0.2489 - val_mse: 0.2489
# Epoch 23/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2394 - mse: 0.2394 - val_loss: 0.2412 - val_mse: 0.2412
# Epoch 24/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2309 - mse: 0.2309 - val_loss: 0.2242 - val_mse: 0.2242
# Epoch 25/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2308 - mse: 0.2308 - val_loss: 0.2213 - val_mse: 0.2213
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2169 - mse: 0.2169 - val_loss: 0.2055 - val_mse: 0.2055
# Epoch 27/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1990 - mse: 0.1990 - val_loss: 0.1929 - val_mse: 0.1929
# Epoch 28/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.1842 - val_mse: 0.1842
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1810 - mse: 0.1810 - val_loss: 0.1745 - val_mse: 0.1745
# Epoch 30/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1758 - mse: 0.1758 - val_loss: 0.1713 - val_mse: 0.1713
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1694 - mse: 0.1694 - val_loss: 0.1673 - val_mse: 0.1673
# Epoch 32/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1667 - mse: 0.1667 - val_loss: 0.1532 - val_mse: 0.1532
# Epoch 33/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1677 - mse: 0.1677 - val_loss: 0.1471 - val_mse: 0.1471
# Epoch 34/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1468 - mse: 0.1468 - val_loss: 0.1655 - val_mse: 0.1655
# Epoch 35/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1443 - mse: 0.1443 - val_loss: 0.1383 - val_mse: 0.1383
# Epoch 36/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1415 - mse: 0.1415 - val_loss: 0.1312 - val_mse: 0.1312
# Epoch 37/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1377 - mse: 0.1377 - val_loss: 0.1286 - val_mse: 0.1286
# Epoch 38/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1304 - mse: 0.1304 - val_loss: 0.1253 - val_mse: 0.1253
# Epoch 39/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1263 - mse: 0.1263 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 40/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1275 - mse: 0.1275 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 41/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1299 - mse: 0.1299 - val_loss: 0.1197 - val_mse: 0.1197
# Epoch 42/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1298 - mse: 0.1298 - val_loss: 0.1277 - val_mse: 0.1277
# Epoch 43/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1308 - mse: 0.1308 - val_loss: 0.1198 - val_mse: 0.1198
# Epoch 44/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1229 - mse: 0.1229 - val_loss: 0.1383 - val_mse: 0.1383
# Epoch 45/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1222 - mse: 0.1222 - val_loss: 0.1169 - val_mse: 0.1169
# Epoch 46/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1205 - mse: 0.1205 - val_loss: 0.1188 - val_mse: 0.1188
# Epoch 47/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1195 - mse: 0.1195 - val_loss: 0.1241 - val_mse: 0.1241
# Epoch 48/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1142 - mse: 0.1142 - val_loss: 0.1198 - val_mse: 0.1198
# Epoch 49/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1156 - mse: 0.1156 - val_loss: 0.1273 - val_mse: 0.1273
# Epoch 50/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1144 - mse: 0.1144 - val_loss: 0.1163 - val_mse: 0.1163
# Epoch 51/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1163 - mse: 0.1163 - val_loss: 0.1315 - val_mse: 0.1315
# Epoch 52/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1211 - mse: 0.1211 - val_loss: 0.1161 - val_mse: 0.1161
# Epoch 53/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1174 - mse: 0.1174 - val_loss: 0.1124 - val_mse: 0.1124
# Epoch 54/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1133 - mse: 0.1133 - val_loss: 0.1130 - val_mse: 0.1130
# Epoch 55/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1162 - mse: 0.1162 - val_loss: 0.1114 - val_mse: 0.1114
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1124 - mse: 0.1124 - val_loss: 0.1111 - val_mse: 0.1111
# Epoch 57/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1134 - mse: 0.1134 - val_loss: 0.1125 - val_mse: 0.1125
# Epoch 58/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1131 - mse: 0.1131 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 59/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1152 - mse: 0.1152 - val_loss: 0.1156 - val_mse: 0.1156
# Epoch 60/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1096 - mse: 0.1096 - val_loss: 0.1110 - val_mse: 0.1110
# Epoch 61/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1165 - mse: 0.1165 - val_loss: 0.1221 - val_mse: 0.1221
# Epoch 62/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1149 - mse: 0.1149 - val_loss: 0.1102 - val_mse: 0.1102
# Epoch 63/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1140 - mse: 0.1140 - val_loss: 0.1241 - val_mse: 0.1241
# Epoch 64/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1252 - mse: 0.1252 - val_loss: 0.1151 - val_mse: 0.1151
# Epoch 65/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1197 - mse: 0.1197 - val_loss: 0.1162 - val_mse: 0.1162
# Epoch 66/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1140 - mse: 0.1140 - val_loss: 0.1227 - val_mse: 0.1227
# Epoch 67/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1143 - mse: 0.1143 - val_loss: 0.1110 - val_mse: 0.1110
# Epoch 68/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1127 - mse: 0.1127 - val_loss: 0.1192 - val_mse: 0.1192
# Epoch 69/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1157 - mse: 0.1157 - val_loss: 0.1188 - val_mse: 0.1188
# Epoch 70/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1087 - val_mse: 0.1087
# Epoch 71/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1099 - mse: 0.1099 - val_loss: 0.1068 - val_mse: 0.1068
# Epoch 72/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1103 - mse: 0.1103 - val_loss: 0.1078 - val_mse: 0.1078
# Epoch 73/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1112 - mse: 0.1112 - val_loss: 0.1311 - val_mse: 0.1311
# Epoch 74/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1169 - mse: 0.1169 - val_loss: 0.1140 - val_mse: 0.1140
# Epoch 75/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1046 - mse: 0.1046 - val_loss: 0.1049 - val_mse: 0.1049
# Epoch 76/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1115 - mse: 0.1115 - val_loss: 0.1048 - val_mse: 0.1048
# Epoch 77/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1052 - mse: 0.1052 - val_loss: 0.1169 - val_mse: 0.1169
# Epoch 78/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1096 - mse: 0.1096 - val_loss: 0.1037 - val_mse: 0.1037
# Epoch 79/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1034 - mse: 0.1034 - val_loss: 0.1050 - val_mse: 0.1050
# Epoch 80/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1069 - mse: 0.1069 - val_loss: 0.1093 - val_mse: 0.1093
# Epoch 81/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1078 - mse: 0.1078 - val_loss: 0.1047 - val_mse: 0.1047
# Epoch 82/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1022 - mse: 0.1022 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 83/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1049 - mse: 0.1049 - val_loss: 0.1090 - val_mse: 0.1090
# Epoch 84/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1034 - mse: 0.1034 - val_loss: 0.1230 - val_mse: 0.1230
# Epoch 85/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1020 - mse: 0.1020 - val_loss: 0.1036 - val_mse: 0.1036
# Epoch 86/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1026 - mse: 0.1026 - val_loss: 0.1016 - val_mse: 0.1016
# Epoch 87/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1007 - mse: 0.1007 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 88/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0988 - mse: 0.0988 - val_loss: 0.1145 - val_mse: 0.1145
# Epoch 89/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1028 - mse: 0.1028 - val_loss: 0.1132 - val_mse: 0.1132
# Epoch 90/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1025 - val_mse: 0.1025
# Epoch 91/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1066 - mse: 0.1066 - val_loss: 0.0999 - val_mse: 0.0999
# Epoch 92/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0980 - mse: 0.0980 - val_loss: 0.1089 - val_mse: 0.1089
# Epoch 93/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0993 - mse: 0.0993 - val_loss: 0.0989 - val_mse: 0.0989
# Epoch 94/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0979 - mse: 0.0979 - val_loss: 0.1079 - val_mse: 0.1079
# Epoch 95/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0982 - mse: 0.0982 - val_loss: 0.1020 - val_mse: 0.1020
# Epoch 96/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1004 - mse: 0.1004 - val_loss: 0.1118 - val_mse: 0.1118
# Epoch 97/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1031 - mse: 0.1031 - val_loss: 0.1101 - val_mse: 0.1101
# Epoch 98/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1045 - mse: 0.1045 - val_loss: 0.1006 - val_mse: 0.1006
# Epoch 99/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1093 - mse: 0.1093 - val_loss: 0.1013 - val_mse: 0.1013
# Epoch 100/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1258 - val_mse: 0.1258

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()
# Out:
#         loss       mse  val_loss   val_mse  epoch
# 95  0.100392  0.100392  0.111835  0.111835     95
# 96  0.103050  0.103050  0.110145  0.110145     96
# 97  0.104543  0.104543  0.100563  0.100563     97
# 98  0.109265  0.109265  0.101291  0.101291     98
# 99  0.108251  0.108251  0.125830  0.125830     99

# %% [markdown]
# ## Evaluation

# %%
yhat = model.predict(X_test, verbose=1)
rms += [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms
# Out:
# 10/10 [==============================] - 0s 2ms/step
# [[20.512938  20.481354 ]
#  [16.445215  16.516975 ]
#  [16.049189  16.132568 ]
#  [19.194313  19.196644 ]
#  [ 7.960776   7.9825234]]
# [0.31810299249074997, 0.3547247337248267]

# %%
plt.figure(figsize=(15,6))
for i in range(n_future):
  plt.subplot(1,n_future,i+1)
  plt.scatter(y_test.index,y_test.iloc[:,i], label = "true Local_X at t+{}".format(i),marker = 'X', )
  plt.scatter(y_test.index,yhat[:,i], label = "prediction Local_X at t+{}".format(i),marker = '.')
  plt.legend()
plt.show()

# %% [markdown]
# # Model 3
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 3|Add multi input series|1|**2**|1|0|4|2|

# %% [markdown]
# ## Data preparation
#
# We will add one more feature v_Vel to the data set used in model 1 and 2

# %%
n_steps = 4
n_future = 2
n_features = 2
feature_names = ['Local_X','v_Vel']
target_names = ['Local_X']
n_labels = len(target_names)
n_features = len(feature_names)

# %% [markdown]
# ### series2seq2: Function that return sequence input and output| Version 2
#
# **Arguments**:
#
# - data: Sequence of observations as a list or NumPy array.
# - n_in: Number of lag observations as input (X).
# - n_out: Number of observations as output (y).
# - **labels**: name of target variables
# - dropnan: Boolean whether or not to drop rows with NaN values.
#
# **Returns**:
# - X: Feature Pandas DataFrame
# - y: Label Pandas dataframe

# %%
def series2seq2(data, n_in=1, n_out=1,labels=None, dropnan=True):

    dat = data.copy()
    if isinstance(dat,pd.Series):
      features = [dat.name]
      targets = [dat.name]
    else:
      features = dat.columns
      if labels == None:
        targets = dat.columns
      else:
        targets = labels
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(dat.shift(i))
        names += ['{}(t-{})'.format(j, i) for j in features ]
    # forecast sequence (t, t+1, ... t+n) for selected labels
    for i in range(0, n_out):
        cols.append(dat[targets].shift(-i))
        if i == 0:
            names += ['{}(t)'.format(j) for j in targets]
        else:
            names += ['{}(t+{})'.format(j, i) for j in targets]
    # put it all together
    agg = pd.concat(cols, axis=1)
    
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    X = agg.iloc[:,:len(features)*n_in]
    y = agg.iloc[:,len(features)*n_in:].copy()
    print(X.head(), X.shape)
    print(y.head(), y.shape)
    return X, y
  
# Test the function
X, y = series2seq2(df[feature_names], n_in=2, n_out=1,labels = target_names, dropnan=False)
# Out:
#    Local_X(t-2)  v_Vel(t-2)  Local_X(t-1)  v_Vel(t-1)
# 0           NaN         NaN           NaN         NaN
# 1           NaN         NaN     16.467196   40.000000
# 2     16.467196   40.000000     16.446594   40.012349
# 3     16.446594   40.012349     16.425991   39.999855
# 4     16.425991   39.999855     16.405392   39.992920 (1048575, 4)
#    Local_X(t)
# 0   16.467196
# 1   16.446594
# 2   16.425991
# 3   16.405392
# 4   16.384804 (1048575, 1)

# %%
X, y = series2seq2(simple_df[feature_names], n_in=n_steps, n_out=n_future,labels = target_names, dropnan=True)
# Out:
#         Local_X(t-4)  v_Vel(t-4)  ...  Local_X(t-1)  v_Vel(t-1)
# 932106      4.725434   45.030000  ...      4.646575   45.187921
# 932107      4.694650   44.490366  ...      4.627103   45.298705
# 932108      4.668727   44.918464  ...      4.609221   45.250796
# 932109      4.646575   45.187921  ...      4.591890   44.961476
# 932110      4.627103   45.298705  ...      4.571389   44.518607
#
# [5 rows x 8 columns] (1005, 8)
#         Local_X(t)  Local_X(t+1)
# 932106    4.627103      4.609221
# 932107    4.609221      4.591890
# 932108    4.591890      4.571389
# 932109    4.571389      4.543895
# 932110    4.543895      4.515965 (1005, 2)

# %% [markdown]
# ### Split the data set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)
# Out:
# (703, 8) (302, 8) (703, 2) (302, 2)

# %%
### Standardize the data
train_mean = X_train.mean()
train_std = X_train.std()

X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print(X_train.shape)
X_train.describe()
# Out:
# (703, 8)
#        Local_X(t-4)    v_Vel(t-4)  ...  Local_X(t-1)    v_Vel(t-1)
# count  7.030000e+02  7.030000e+02  ...  7.030000e+02  7.030000e+02
# mean  -3.787077e-16  1.285013e-15  ...  7.615214e-16 -2.524652e-15
# std    1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
# min   -1.575110e+00 -1.665909e+00  ... -1.585490e+00 -1.674027e+00
# 25%   -1.067267e+00 -8.310449e-01  ... -1.077957e+00 -8.338836e-01
# 50%    4.144181e-01  1.120130e-02  ...  4.104574e-01  1.399114e-02
# 75%    9.633450e-01  8.446867e-01  ...  9.610258e-01  8.547545e-01
# max    1.268899e+00  2.124380e+00  ...  1.267863e+00  2.144042e+00
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')


# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 0s 17ms/step - loss: 218.6739 - mse: 218.6739 - val_loss: 209.1932 - val_mse: 209.1932
# Epoch 2/100
# 22/22 [==============================] - 0s 7ms/step - loss: 198.3735 - mse: 198.3735 - val_loss: 132.8519 - val_mse: 132.8519
# Epoch 3/100
# 22/22 [==============================] - 0s 7ms/step - loss: 70.2554 - mse: 70.2554 - val_loss: 48.0716 - val_mse: 48.0716
# Epoch 4/100
# 22/22 [==============================] - 0s 7ms/step - loss: 40.9709 - mse: 40.9709 - val_loss: 33.1634 - val_mse: 33.1634
# Epoch 5/100
# 22/22 [==============================] - 0s 7ms/step - loss: 29.3135 - mse: 29.3135 - val_loss: 23.7289 - val_mse: 23.7289
# Epoch 6/100
# 22/22 [==============================] - 0s 7ms/step - loss: 21.0163 - mse: 21.0163 - val_loss: 19.1759 - val_mse: 19.1759
# Epoch 7/100
# 22/22 [==============================] - 0s 7ms/step - loss: 14.2063 - mse: 14.2063 - val_loss: 12.3509 - val_mse: 12.3509
# Epoch 8/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.6725 - mse: 9.6725 - val_loss: 7.8198 - val_mse: 7.8198
# Epoch 9/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.4259 - mse: 6.4259 - val_loss: 4.7254 - val_mse: 4.7254
# Epoch 10/100
# 22/22 [==============================] - 0s 7ms/step - loss: 4.0570 - mse: 4.0570 - val_loss: 3.1059 - val_mse: 3.1059
# Epoch 11/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.6083 - mse: 2.6083 - val_loss: 2.2300 - val_mse: 2.2300
# Epoch 12/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.9224 - mse: 1.9224 - val_loss: 1.5883 - val_mse: 1.5883
# Epoch 13/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.4889 - mse: 1.4889 - val_loss: 1.2841 - val_mse: 1.2841
# Epoch 14/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.1924 - mse: 1.1924 - val_loss: 1.0439 - val_mse: 1.0439
# Epoch 15/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.9829 - mse: 0.9829 - val_loss: 0.8968 - val_mse: 0.8968
# Epoch 16/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8250 - mse: 0.8250 - val_loss: 0.7603 - val_mse: 0.7603
# Epoch 17/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6975 - mse: 0.6975 - val_loss: 0.6537 - val_mse: 0.6537
# Epoch 18/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6050 - mse: 0.6050 - val_loss: 0.5665 - val_mse: 0.5665
# Epoch 19/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5438 - mse: 0.5438 - val_loss: 0.5149 - val_mse: 0.5149
# Epoch 20/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.4734 - mse: 0.4734 - val_loss: 0.4748 - val_mse: 0.4748
# Epoch 21/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.4297 - mse: 0.4297 - val_loss: 0.4215 - val_mse: 0.4215
# Epoch 22/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.4037 - mse: 0.4037 - val_loss: 0.3979 - val_mse: 0.3979
# Epoch 23/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3829 - mse: 0.3829 - val_loss: 0.3782 - val_mse: 0.3782
# Epoch 24/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3706 - mse: 0.3706 - val_loss: 0.3673 - val_mse: 0.3673
# Epoch 25/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3671 - mse: 0.3671 - val_loss: 0.3957 - val_mse: 0.3957
# Epoch 26/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3627 - mse: 0.3627 - val_loss: 0.3474 - val_mse: 0.3474
# Epoch 27/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3404 - mse: 0.3404 - val_loss: 0.4322 - val_mse: 0.4322
# Epoch 28/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3449 - mse: 0.3449 - val_loss: 0.3406 - val_mse: 0.3406
# Epoch 29/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3426 - mse: 0.3426 - val_loss: 0.3216 - val_mse: 0.3216
# Epoch 30/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3604 - mse: 0.3604 - val_loss: 0.3440 - val_mse: 0.3440
# Epoch 31/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3580 - mse: 0.3580 - val_loss: 0.4202 - val_mse: 0.4202
# Epoch 32/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3541 - mse: 0.3541 - val_loss: 0.3220 - val_mse: 0.3220
# Epoch 33/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3603 - mse: 0.3603 - val_loss: 0.3999 - val_mse: 0.3999
# Epoch 34/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3410 - mse: 0.3410 - val_loss: 0.4463 - val_mse: 0.4463
# Epoch 35/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3262 - mse: 0.3262 - val_loss: 0.3727 - val_mse: 0.3727
# Epoch 36/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3143 - mse: 0.3143 - val_loss: 0.3178 - val_mse: 0.3178
# Epoch 37/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3013 - mse: 0.3013 - val_loss: 0.3063 - val_mse: 0.3063
# Epoch 38/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2935 - mse: 0.2935 - val_loss: 0.3089 - val_mse: 0.3089
# Epoch 39/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3003 - mse: 0.3003 - val_loss: 0.3057 - val_mse: 0.3057
# Epoch 40/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3096 - mse: 0.3096 - val_loss: 0.2953 - val_mse: 0.2953
# Epoch 41/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3242 - mse: 0.3242 - val_loss: 0.3955 - val_mse: 0.3955
# Epoch 42/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3544 - mse: 0.3544 - val_loss: 0.4143 - val_mse: 0.4143
# Epoch 43/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3577 - mse: 0.3577 - val_loss: 0.2874 - val_mse: 0.2874
# Epoch 44/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3182 - mse: 0.3182 - val_loss: 0.2982 - val_mse: 0.2982
# Epoch 45/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2959 - mse: 0.2959 - val_loss: 0.3429 - val_mse: 0.3429
# Epoch 46/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3877 - mse: 0.3877 - val_loss: 0.3007 - val_mse: 0.3007
# Epoch 47/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3238 - mse: 0.3238 - val_loss: 0.3091 - val_mse: 0.3091
# Epoch 48/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2822 - mse: 0.2822 - val_loss: 0.3682 - val_mse: 0.3682
# Epoch 49/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2968 - mse: 0.2968 - val_loss: 0.2803 - val_mse: 0.2803
# Epoch 50/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2925 - mse: 0.2925 - val_loss: 0.2776 - val_mse: 0.2776
# Epoch 51/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2823 - mse: 0.2823 - val_loss: 0.2733 - val_mse: 0.2733
# Epoch 52/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2700 - mse: 0.2700 - val_loss: 0.2607 - val_mse: 0.2607
# Epoch 53/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2870 - mse: 0.2870 - val_loss: 0.2586 - val_mse: 0.2586
# Epoch 54/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3075 - mse: 0.3075 - val_loss: 0.2939 - val_mse: 0.2939
# Epoch 55/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2871 - mse: 0.2871 - val_loss: 0.2668 - val_mse: 0.2668
# Epoch 56/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2848 - mse: 0.2848 - val_loss: 0.2567 - val_mse: 0.2567
# Epoch 57/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2852 - mse: 0.2852 - val_loss: 0.2718 - val_mse: 0.2718
# Epoch 58/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2876 - mse: 0.2876 - val_loss: 0.2929 - val_mse: 0.2929
# Epoch 59/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2989 - mse: 0.2989 - val_loss: 0.2542 - val_mse: 0.2542
# Epoch 60/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2609 - mse: 0.2609 - val_loss: 0.2994 - val_mse: 0.2994
# Epoch 61/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2662 - mse: 0.2662 - val_loss: 0.2475 - val_mse: 0.2475
# Epoch 62/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2669 - mse: 0.2669 - val_loss: 0.2593 - val_mse: 0.2593
# Epoch 63/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2891 - mse: 0.2891 - val_loss: 0.3081 - val_mse: 0.3081
# Epoch 64/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2575 - mse: 0.2575 - val_loss: 0.2470 - val_mse: 0.2470
# Epoch 65/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2497 - mse: 0.2497 - val_loss: 0.2540 - val_mse: 0.2540
# Epoch 66/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2499 - mse: 0.2499 - val_loss: 0.2486 - val_mse: 0.2486
# Epoch 67/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2569 - mse: 0.2569 - val_loss: 0.2493 - val_mse: 0.2493
# Epoch 68/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2571 - mse: 0.2571 - val_loss: 0.2482 - val_mse: 0.2482
# Epoch 69/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2670 - mse: 0.2670 - val_loss: 0.2577 - val_mse: 0.2577
# Epoch 70/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2647 - mse: 0.2647 - val_loss: 0.2376 - val_mse: 0.2376
# Epoch 71/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2710 - mse: 0.2710 - val_loss: 0.2738 - val_mse: 0.2738
# Epoch 72/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2708 - mse: 0.2708 - val_loss: 0.2509 - val_mse: 0.2509
# Epoch 73/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2923 - mse: 0.2923 - val_loss: 0.2380 - val_mse: 0.2380
# Epoch 74/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2660 - mse: 0.2660 - val_loss: 0.3456 - val_mse: 0.3456
# Epoch 75/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2607 - mse: 0.2607 - val_loss: 0.3314 - val_mse: 0.3314
# Epoch 76/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2969 - mse: 0.2969 - val_loss: 0.2494 - val_mse: 0.2494
# Epoch 77/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2863 - mse: 0.2863 - val_loss: 0.3275 - val_mse: 0.3275
# Epoch 78/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2627 - mse: 0.2627 - val_loss: 0.2503 - val_mse: 0.2503
# Epoch 79/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2236 - val_mse: 0.2236
# Epoch 80/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2455 - mse: 0.2455 - val_loss: 0.2415 - val_mse: 0.2415
# Epoch 81/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2352 - mse: 0.2352 - val_loss: 0.2747 - val_mse: 0.2747
# Epoch 82/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2336 - mse: 0.2336 - val_loss: 0.2152 - val_mse: 0.2152
# Epoch 83/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2679 - mse: 0.2679 - val_loss: 0.2596 - val_mse: 0.2596
# Epoch 84/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2548 - mse: 0.2548 - val_loss: 0.3472 - val_mse: 0.3472
# Epoch 85/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2937 - mse: 0.2937 - val_loss: 0.2184 - val_mse: 0.2184
# Epoch 86/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2642 - mse: 0.2642 - val_loss: 0.2237 - val_mse: 0.2237
# Epoch 87/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2634 - mse: 0.2634 - val_loss: 0.2097 - val_mse: 0.2097
# Epoch 88/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2945 - mse: 0.2945 - val_loss: 0.3019 - val_mse: 0.3019
# Epoch 89/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3354 - mse: 0.3354 - val_loss: 0.4673 - val_mse: 0.4673
# Epoch 90/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2860 - mse: 0.2860 - val_loss: 0.2050 - val_mse: 0.2050
# Epoch 91/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2491 - mse: 0.2491 - val_loss: 0.2651 - val_mse: 0.2651
# Epoch 92/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2463 - mse: 0.2463 - val_loss: 0.2221 - val_mse: 0.2221
# Epoch 93/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 0.2277 - val_mse: 0.2277
# Epoch 94/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2383 - mse: 0.2383 - val_loss: 0.2385 - val_mse: 0.2385
# Epoch 95/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2514 - mse: 0.2514 - val_loss: 0.1967 - val_mse: 0.1967
# Epoch 96/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2893 - mse: 0.2893 - val_loss: 0.2910 - val_mse: 0.2910
# Epoch 97/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2419 - mse: 0.2419 - val_loss: 0.2055 - val_mse: 0.2055
# Epoch 98/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2196 - mse: 0.2196 - val_loss: 0.2269 - val_mse: 0.2269
# Epoch 99/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2463 - mse: 0.2463 - val_loss: 0.1940 - val_mse: 0.1940
# Epoch 100/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2815 - mse: 0.2815 - val_loss: 0.2777 - val_mse: 0.2777

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()
# Out:
#         loss       mse  val_loss   val_mse  epoch
# 95  0.289255  0.289255  0.291023  0.291023     95
# 96  0.241897  0.241897  0.205528  0.205528     96
# 97  0.219575  0.219575  0.226874  0.226874     97
# 98  0.246345  0.246345  0.193983  0.193983     98
# 99  0.281513  0.281513  0.277673  0.277673     99

# %% [markdown]
# ## Evaluation

# %%
yhat = model.predict(X_test, verbose=1)
rms += [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms
# Out:
# 10/10 [==============================] - 0s 2ms/step
# [[21.261696 21.262363]
#  [16.94269  16.917667]
#  [16.740871 16.713097]
#  [19.846342 19.877695]
#  [ 8.191774  8.189618]]
# [0.31810299249074997, 0.3547247337248267, 0.5269472090785062]

# %%
plt.figure(figsize=(15,6))
k = 1
for i in range(n_future):
  for j in range(1,n_labels+1):
    plt.subplot(j,n_future,k)
    plt.scatter(y_test.index,y_test.iloc[:,i], label = "true Local_X at t+{}".format(i),marker = 'X', )
    plt.scatter(y_test.index,yhat[:,i], label = "prediction Local_X at t+{}".format(i),marker = '.')
    plt.legend()
    k+=1
plt.show()

# %% [markdown]
# # Model 4
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 4|Add multi `output` series|1|2|**2**|0|4|2|

# %% [markdown]
# ## Data preparation
#
# We will use the same dataset of model 3

# %%
n_steps = 4
n_future = 2
n_features = 2
feature_names = ['Local_X','v_Vel']
target_names = ['Local_X','v_Vel']
n_labels = len(target_names)
n_features = len(feature_names)

# %%
X, y = series2seq2(simple_df[feature_names], n_in=n_steps, n_out=n_future,labels = target_names, dropnan=True)
# Out:
#         Local_X(t-4)  v_Vel(t-4)  ...  Local_X(t-1)  v_Vel(t-1)
# 932106      4.725434   45.030000  ...      4.646575   45.187921
# 932107      4.694650   44.490366  ...      4.627103   45.298705
# 932108      4.668727   44.918464  ...      4.609221   45.250796
# 932109      4.646575   45.187921  ...      4.591890   44.961476
# 932110      4.627103   45.298705  ...      4.571389   44.518607
#
# [5 rows x 8 columns] (1005, 8)
#         Local_X(t)   v_Vel(t)  Local_X(t+1)  v_Vel(t+1)
# 932106    4.627103  45.298705      4.609221   45.250796
# 932107    4.609221  45.250796      4.591890   44.961476
# 932108    4.591890  44.961476      4.571389   44.518607
# 932109    4.571389  44.518607      4.543895   44.002607
# 932110    4.543895  44.002607      4.515965   43.534859 (1005, 4)

# %% [markdown]
# ### Split the data set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)
# Out:
# (703, 8) (302, 8) (703, 4) (302, 4)

# %%
### Standardize the data
train_mean = X_train.mean()
train_std = X_train.std()

X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print(X_train.shape)
X_train.describe()
# Out:
# (703, 8)
#        Local_X(t-4)    v_Vel(t-4)  ...  Local_X(t-1)    v_Vel(t-1)
# count  7.030000e+02  7.030000e+02  ...  7.030000e+02  7.030000e+02
# mean  -3.787077e-16  1.285013e-15  ...  7.615214e-16 -2.524652e-15
# std    1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
# min   -1.575110e+00 -1.665909e+00  ... -1.585490e+00 -1.674027e+00
# 25%   -1.067267e+00 -8.310449e-01  ... -1.077957e+00 -8.338836e-01
# 50%    4.144181e-01  1.120130e-02  ...  4.104574e-01  1.399114e-02
# 75%    9.633450e-01  8.446867e-01  ...  9.610258e-01  8.547545e-01
# max    1.268899e+00  2.124380e+00  ...  1.267863e+00  2.144042e+00
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')


# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 0s 15ms/step - loss: 373.7903 - mse: 373.7903 - val_loss: 418.7645 - val_mse: 418.7645
# Epoch 2/100
# 22/22 [==============================] - 0s 6ms/step - loss: 353.3907 - mse: 353.3907 - val_loss: 338.1276 - val_mse: 338.1276
# Epoch 3/100
# 22/22 [==============================] - 0s 6ms/step - loss: 146.9411 - mse: 146.9411 - val_loss: 103.8713 - val_mse: 103.8713
# Epoch 4/100
# 22/22 [==============================] - 0s 6ms/step - loss: 79.5960 - mse: 79.5960 - val_loss: 87.7487 - val_mse: 87.7487
# Epoch 5/100
# 22/22 [==============================] - 0s 6ms/step - loss: 69.5022 - mse: 69.5022 - val_loss: 72.8973 - val_mse: 72.8973
# Epoch 6/100
# 22/22 [==============================] - 0s 6ms/step - loss: 63.7572 - mse: 63.7572 - val_loss: 68.9629 - val_mse: 68.9629
# Epoch 7/100
# 22/22 [==============================] - 0s 6ms/step - loss: 59.4299 - mse: 59.4299 - val_loss: 62.8469 - val_mse: 62.8469
# Epoch 8/100
# 22/22 [==============================] - 0s 6ms/step - loss: 55.9256 - mse: 55.9256 - val_loss: 59.4756 - val_mse: 59.4756
# Epoch 9/100
# 22/22 [==============================] - 0s 6ms/step - loss: 53.3451 - mse: 53.3451 - val_loss: 56.2319 - val_mse: 56.2319
# Epoch 10/100
# 22/22 [==============================] - 0s 6ms/step - loss: 50.6613 - mse: 50.6613 - val_loss: 52.3418 - val_mse: 52.3418
# Epoch 11/100
# 22/22 [==============================] - 0s 7ms/step - loss: 47.5383 - mse: 47.5383 - val_loss: 48.7718 - val_mse: 48.7718
# Epoch 12/100
# 22/22 [==============================] - 0s 6ms/step - loss: 44.2891 - mse: 44.2891 - val_loss: 44.7508 - val_mse: 44.7508
# Epoch 13/100
# 22/22 [==============================] - 0s 6ms/step - loss: 40.4422 - mse: 40.4422 - val_loss: 39.5310 - val_mse: 39.5310
# Epoch 14/100
# 22/22 [==============================] - 0s 6ms/step - loss: 36.0437 - mse: 36.0437 - val_loss: 35.1948 - val_mse: 35.1948
# Epoch 15/100
# 22/22 [==============================] - 0s 6ms/step - loss: 31.3836 - mse: 31.3836 - val_loss: 30.0188 - val_mse: 30.0188
# Epoch 16/100
# 22/22 [==============================] - 0s 6ms/step - loss: 24.1645 - mse: 24.1645 - val_loss: 18.5988 - val_mse: 18.5988
# Epoch 17/100
# 22/22 [==============================] - 0s 6ms/step - loss: 11.2074 - mse: 11.2074 - val_loss: 7.3678 - val_mse: 7.3678
# Epoch 18/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.0014 - mse: 6.0014 - val_loss: 4.6559 - val_mse: 4.6559
# Epoch 19/100
# 22/22 [==============================] - 0s 6ms/step - loss: 4.0631 - mse: 4.0631 - val_loss: 3.4484 - val_mse: 3.4484
# Epoch 20/100
# 22/22 [==============================] - 0s 6ms/step - loss: 3.0945 - mse: 3.0945 - val_loss: 2.9143 - val_mse: 2.9143
# Epoch 21/100
# 22/22 [==============================] - 0s 6ms/step - loss: 2.6374 - mse: 2.6374 - val_loss: 2.4313 - val_mse: 2.4313
# Epoch 22/100
# 22/22 [==============================] - 0s 6ms/step - loss: 2.1979 - mse: 2.1979 - val_loss: 2.0235 - val_mse: 2.0235
# Epoch 23/100
# 22/22 [==============================] - 0s 6ms/step - loss: 2.1028 - mse: 2.1028 - val_loss: 2.5147 - val_mse: 2.5147
# Epoch 24/100
# 22/22 [==============================] - 0s 6ms/step - loss: 2.0173 - mse: 2.0173 - val_loss: 2.1806 - val_mse: 2.1806
# Epoch 25/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.8969 - mse: 1.8969 - val_loss: 1.7467 - val_mse: 1.7467
# Epoch 26/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.5823 - mse: 1.5823 - val_loss: 1.3868 - val_mse: 1.3868
# Epoch 27/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.5005 - mse: 1.5005 - val_loss: 1.3411 - val_mse: 1.3411
# Epoch 28/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.5005 - mse: 1.5005 - val_loss: 1.5636 - val_mse: 1.5636
# Epoch 29/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.4481 - mse: 1.4481 - val_loss: 1.2443 - val_mse: 1.2443
# Epoch 30/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.3563 - mse: 1.3563 - val_loss: 1.1716 - val_mse: 1.1716
# Epoch 31/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.3666 - mse: 1.3666 - val_loss: 1.1846 - val_mse: 1.1846
# Epoch 32/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2945 - mse: 1.2945 - val_loss: 1.1246 - val_mse: 1.1246
# Epoch 33/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.2690 - mse: 1.2690 - val_loss: 1.1615 - val_mse: 1.1615
# Epoch 34/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.2722 - mse: 1.2722 - val_loss: 1.0715 - val_mse: 1.0715
# Epoch 35/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2454 - mse: 1.2454 - val_loss: 1.1625 - val_mse: 1.1625
# Epoch 36/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2097 - mse: 1.2097 - val_loss: 1.1417 - val_mse: 1.1417
# Epoch 37/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2452 - mse: 1.2452 - val_loss: 1.0829 - val_mse: 1.0829
# Epoch 38/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2211 - mse: 1.2211 - val_loss: 1.0531 - val_mse: 1.0531
# Epoch 39/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1700 - mse: 1.1700 - val_loss: 1.0284 - val_mse: 1.0284
# Epoch 40/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1801 - mse: 1.1801 - val_loss: 0.9904 - val_mse: 0.9904
# Epoch 41/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1657 - mse: 1.1657 - val_loss: 1.2054 - val_mse: 1.2054
# Epoch 42/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1960 - mse: 1.1960 - val_loss: 1.0122 - val_mse: 1.0122
# Epoch 43/100
# 12/22 [===============>..............] - ETA: 0s - loss: 1.4017 - mse: 1.4017

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()

# %% [markdown]
# ## Evaluation

# %%
yhat = model.predict(X_test, verbose=1)
rms += [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms

# %%
plt.figure(figsize=(n_labels*5,n_future*5))
k = 1
for i in range(n_future):
  for j in range(1,n_labels+1):
    plt.subplot(n_labels,n_future,k)
    plt.scatter(y_test.index,y_test.iloc[:,i], label = "true {} at t+{}".format(target_names[j-1],i),marker = 'X', )
    plt.scatter(y_test.index,yhat[:,i], label = "prediction {} at t+{}".format(target_names[j-1],i),marker = '.')
    plt.legend()
    k+=1
plt.show()

# %% [markdown]
# # Model 5
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 5|Add multi constant input|1|2|2|**2**|4|2|

# %% [markdown]
# ## Data preparation
#
# We will add one two constant features `v_Length`, `v_Width` to the data set used in model 3 and 4

# %%
simple_df[[ 'Local_X', 'v_Vel', 'v_Length', 'v_Width']].head()

# %%
n_steps = 4
n_future = 2
n_features = 2
series_feature_names = ['Local_X','v_Vel']
target_names = ['Local_X','v_Vel']
n_labels = len(target_names)
n_features = len(feature_names)
const_feats = []

# %% [markdown]
# ### series2seq3: Function that return sequence input and output| Version 3
#
# **Arguments**:
#
# - data: Sequence of observations as a list or NumPy array.
# - n_in: Number of lag observations as input (X).
# - n_out: Number of observations as output (y).
# - **series_features**: names of series features
# - labels: name of target variables
# - dropnan: Boolean whether or not to drop rows with NaN values.
#
# **Returns**:
# - X: Feature Pandas DataFrame
# - y: Label Pandas dataframe

# %%
def series2seq3(data, n_in=1, n_out=1,labels=None,series_features=None, dropnan=True):

    dat = data.copy()
    # check if the data set is univariable
    if isinstance(dat,pd.Series):
      features = [dat.name]
      targets = [dat.name]
    else:
      features = dat.columns
      if labels == None:
        targets = dat.columns
      else:
        targets = labels
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    if series_features == None:
      for i in range(n_in, 0, -1):
        cols.append(dat.shift(i))
        names += ['{}(t-{})'.format(j, i) for j in features ]
    else:
      for i in range(n_in, 0, -1):
        cols.append(dat[series_features].shift(i))
        names += ['{}(t-{})'.format(j, i) for j in series_features]
    # forecast sequence (t, t+1, ... t+n) for selected labels
    #print(targets)
    for i in range(0, n_out):
        cols.append(dat[targets].shift(-i))
        if i == 0:
            names += ['{}(t)'.format(j) for j in targets]
        else:
            names += ['{}(t+{})'.format(j, i) for j in targets]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # concatenate with constant features
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    X = agg.iloc[:,:len(series_features)*n_in]
    X = pd.concat([X,dat.drop(columns=series_features)], axis=1).dropna()
    y = agg.iloc[:,len(series_features)*n_in:].copy()
    #print(X.head(), X.shape)
    #print(y.head(), y.shape)
    return X, y
  
# Test the function
X, y = series2seq3(simple_df[[ 'Local_X', 'v_Vel', 'v_Length', 'v_Width']], n_in=2, n_out=1,labels = target_names,series_features=series_feature_names, dropnan=True)

# %%
X, y = series2seq3(simple_df[[ 'Local_X', 'v_Vel', 'v_Length', 'v_Width']], 
                   n_in=n_steps, n_out=n_future,
                   labels = target_names,
                   series_features=series_feature_names, 
                   dropnan=True)

# %% [markdown]
# ### Split the data set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)

# %%
X_train.describe()

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')


# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()

# %% [markdown]
# ## Evaluation

# %%
yhat = model.predict(X_test, verbose=1)
rms += [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms

# %%
plt.figure(figsize=(n_labels*5,n_future*5))
k = 1
for i in range(n_future):
  for j in range(1,n_labels+1):
    plt.subplot(n_labels,n_future,k)
    plt.scatter(y_test.index,y_test.iloc[:,i], label = "true {} at t+{}".format(target_names[j-1],i),marker = 'X', )
    plt.scatter(y_test.index,yhat[:,i], label = "prediction {} at t+{}".format(target_names[j-1],i),marker = '.')
    plt.legend()
    k+=1
plt.show()

# %% [markdown]
# # Model 6
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 6|Add more objects|**4**|2|2|2|4|2|

# %% [markdown]
# ## Data preparation
#
# We will add 3 more objects to the dataset used in previous models

# %%
np.random.seed(23)
veh_list = np.random.choice(df.Vehicle_ID.unique(),3)
veh_list = np.append(veh_list,2582)
veh_list

# %%
kept_cols = [ 'Vehicle_ID', 'Frame_ID','Local_X', 'v_Vel', 'v_Length', 'v_Width']
simple_df = df[df.Vehicle_ID.isin(veh_list)].copy()[kept_cols]
simple_df.info()
simple_df.head()

# %%
n_steps = 4
n_future = 2
n_features = 2
series_feature_names = ['Local_X','v_Vel']
target_names = ['Local_X','v_Vel']
n_labels = len(target_names)
n_features = len(feature_names)

# %% [markdown]
# ### `treatment_cars` Function to prepare the data set for each car

# %%
def treatment_cars(data, n_in=1, n_out=1,labels=None,series_features=None):
  veh_ids = data.Vehicle_ID.unique()
  dat_X, dat_y = pd.DataFrame(),pd.DataFrame()

  for id in veh_ids:
    dat = data[data.Vehicle_ID==id].copy()
    X, y = series2seq3(dat.drop(columns=['Frame_ID']), n_in=n_in, n_out=n_out,labels = labels,series_features=series_features, dropnan=True)
    dat_X = pd.concat([dat_X,X],ignore_index=True)
    dat_y = pd.concat([dat_y,y],ignore_index=True)
  print(dat_X.shape)
  print(dat_y.shape)
  return dat_X ,dat_y
treatment_cars(simple_df,n_in=2, n_out=1, labels = target_names,series_features=series_feature_names,)

# %%
X, y = treatment_cars(simple_df, 
                   n_in=n_steps, n_out=n_future,
                   labels = target_names,
                   series_features=series_feature_names)

# %%
X.Vehicle_ID.unique()

# %% [markdown]
# ### Split the data set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)

# %%
X_train.describe()

# %%
### Standardize the data
train_mean = X_train.mean()
train_std = X_train.std()

X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print(X_train.shape)
X_train.describe()

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')


# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()

# %% [markdown]
# ## Evaluation

# %%
yhat = model.predict(X_test, verbose=1)
rms += [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms

# %%
plt.figure(figsize=(n_labels*5,n_future*5))
k = 1
for i in range(n_future):
  for j in range(1,n_labels+1):
    plt.subplot(n_labels,n_future,k)
    plt.scatter(y_test.index,y_test.iloc[:,j], label = "true {} at t+{}".format(target_names[j-1],i),marker = 'X', )
    plt.scatter(y_test.index,yhat[:,j], label = "prediction {} at t+{}".format(target_names[j-1],i),marker = '.')
    plt.legend()
    k+=1
plt.show()

# %% [markdown]
# # 1000 cars

# %% [markdown]
# ## Data preparation
#
# We will add 3 more objects to the dataset used in previous models

# %%
np.random.seed(23)
veh_list = np.random.choice(df.Vehicle_ID.unique(),1000)

# %%
kept_cols = [ 'Vehicle_ID', 'Frame_ID','Local_X', 'v_Vel', 'v_Length', 'v_Width']
simple_df = df[df.Vehicle_ID.isin(veh_list)].copy()[kept_cols]
simple_df.info()
simple_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412788 entries, 1597 to 1048574
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Vehicle_ID  412788 non-null  int64
#  1   Frame_ID    412788 non-null  int64
#  2   Local_X     412788 non-null  float64
#  3   v_Vel       412788 non-null  float64
#  4   v_Length    412788 non-null  float64
#  5   v_Width     412788 non-null  float64
# dtypes: float64(4), int64(2)
# memory usage: 22.0 MB
#       Vehicle_ID  Frame_ID    Local_X      v_Vel  v_Length  v_Width
# 1597           8        29  36.866364  45.000000      15.5      5.4
# 1598           8        30  36.843252  45.026327      15.5      5.4
# 1599           8        31  36.820189  45.005136      15.5      5.4
# 1600           8        32  36.797154  44.991848      15.5      5.4
# 1601           8        33  36.774126  44.986464      15.5      5.4

# %%
n_steps = 4
n_future = 2
n_features = 2
series_feature_names = ['Local_X','v_Vel']
target_names = ['Local_X','v_Vel']
n_labels = len(target_names)
n_features = len(feature_names)

# %% [markdown]
# ### `treatment_cars` Function to prepare the data set for each car

# %%
def treatment_cars(data, n_in=1, n_out=1,labels=None,series_features=None):
  veh_ids = data.Vehicle_ID.unique()
  dat_X, dat_y = pd.DataFrame(),pd.DataFrame()

  for id in veh_ids:
    dat = data[data.Vehicle_ID==id].copy()
    X, y = series2seq3(dat.drop(columns=['Frame_ID']), n_in=n_in, n_out=n_out,labels = labels,series_features=series_features, dropnan=True)
    dat_X = pd.concat([dat_X,X],ignore_index=True)
    dat_y = pd.concat([dat_y,y],ignore_index=True)
  print(dat_X.shape)
  print(dat_y.shape)
  return dat_X ,dat_y
treatment_cars(simple_df,n_in=2, n_out=1, labels = target_names,series_features=series_feature_names,)
# Out:
# (411228, 7)
# (411228, 2)
# (        Local_X(t-2)  v_Vel(t-2)  Local_X(t-1)  ...  Vehicle_ID  v_Length  v_Width
#  0          36.866364   45.000000     36.843252  ...           8      15.5      5.4
#  1          36.843252   45.026327     36.820189  ...           8      15.5      5.4
#  2          36.820189   45.005136     36.797154  ...           8      15.5      5.4
#  3          36.797154   44.991848     36.774126  ...           8      15.5      5.4
#  4          36.774126   44.986464     36.751084  ...           8      15.5      5.4
#  ...              ...         ...           ...  ...         ...       ...      ...
#  411223     55.006387   36.352110     55.080359  ...        2783      17.5      5.4
#  411224     55.080359   35.757582     55.094042  ...        2783      17.5      5.4
#  411225     55.094042   35.417817     55.092441  ...        2783      17.5      5.4
#  411226     55.092441   35.221472     55.091506  ...        2783      17.5      5.4
#  411227     55.091506   35.141983     55.107189  ...        2783      17.5      5.4
#
#  [411228 rows x 7 columns],         Local_X(t)   v_Vel(t)
#  0        36.820189  45.005136
#  1        36.797154  44.991848
#  2        36.774126  44.986464
#  3        36.751084  44.988982
#  4        36.727876  45.088639
#  ...            ...        ...
#  411223   55.094042  35.417817
#  411224   55.092441  35.221472
#  411225   55.091506  35.141983
#  411226   55.107189  35.179440
#  411227   55.155441  35.336092
#
#  [411228 rows x 2 columns])

# %%
X, y = treatment_cars(simple_df, 
                   n_in=n_steps, n_out=n_future,
                   labels = target_names,
                   series_features=series_feature_names)
# Out:
# (408888, 11)
# (408888, 4)

# %%
len(X.Vehicle_ID.unique())
# Out:
# 780

# %% [markdown]
# ### Split the data set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size=0.3, random_state=42)
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape)
# Out:
# (286221, 11) (122667, 11) (286221, 4) (122667, 4)

# %%
X_train.describe()
# Out:
#         Local_X(t-4)     v_Vel(t-4)  ...       v_Length        v_Width
# count  286221.000000  286221.000000  ...  286221.000000  286221.000000
# mean       29.045081      38.441649  ...      14.861266       6.232111
# std        16.490716      14.080375  ...       4.672556       1.027438
# min         1.532359       0.000000  ...       7.500000       2.900000
# 25%        17.258543      30.096309  ...      12.500000       5.400000
# 50%        29.360000      39.748517  ...      14.500000       6.000000
# 75%        41.586056      47.773591  ...      16.500000       6.900000
# max        72.538231      99.712811  ...      61.500000       8.500000
#
# [8 rows x 11 columns]

# %%
### Standardize the data
train_mean = X_train.mean()
train_std = X_train.std()

X_train = (X_train - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print(X_train.shape)
X_train.describe()
# Out:
# (703, 10)
#        Local_X(t-4)    v_Vel(t-4)  ...  v_Length       v_Width
# count  7.030000e+02  7.030000e+02  ...       0.0  7.030000e+02
# mean  -3.787077e-16  1.285013e-15  ...       NaN  9.992885e-01
# std    1.000000e+00  1.000000e+00  ...       NaN  7.665993e-15
# min   -1.575110e+00 -1.665909e+00  ...       NaN  9.992885e-01
# 25%   -1.067267e+00 -8.310449e-01  ...       NaN  9.992885e-01
# 50%    4.144181e-01  1.120130e-02  ...       NaN  9.992885e-01
# 75%    9.633450e-01  8.446867e-01  ...       NaN  9.992885e-01
# max    1.268899e+00  2.124380e+00  ...       NaN  9.992885e-01
#
# [8 rows x 10 columns]

# %% [markdown]
# ### Reshape data sets

# %%
X_train = X_train.values
X_test = X_test.values
# reshape into [# samples, # timesteps,# features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0], X_train.shape[1],1))

# %% [markdown]
# ## Prediction model

# %%
import time
time.time()
# Out:
# 1599095362.8364496

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(n_labels*n_future))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# For saving the best model during the whole training process.
#checkpointer = callbacks.ModelCheckpoint(filepath='BestModel.h5', monitor='val_loss', save_best_only=True)

#### Interrupt training if `val_loss` stops improving for over 10 epochs #######
stop_learn= tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')

start = time.time()
# fit model
Monitor = model.fit(X_train, y_train, epochs=100, 
                    callbacks=[stop_learn],
                    validation_data=(X_test, y_test), verbose=1)
end = time.time()
'Training time was {} sec'.format(end-start)
# Out:
# Epoch 1/100
# 8945/8945 [==============================] - 65s 7ms/step - loss: 13.5191 - mse: 13.5191 - val_loss: 0.5706 - val_mse: 0.5706
# Epoch 2/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.5832 - mse: 0.5832 - val_loss: 0.4684 - val_mse: 0.4684
# Epoch 3/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.3798 - mse: 0.3798 - val_loss: 0.2995 - val_mse: 0.2995
# Epoch 4/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.2918 - mse: 0.2918 - val_loss: 0.2735 - val_mse: 0.2735
# Epoch 5/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.1712 - val_mse: 0.1712
# Epoch 6/100
# 8945/8945 [==============================] - 61s 7ms/step - loss: 0.2163 - mse: 0.2163 - val_loss: 0.6358 - val_mse: 0.6358
# Epoch 7/100
# 8945/8945 [==============================] - 61s 7ms/step - loss: 0.1992 - mse: 0.1992 - val_loss: 0.1389 - val_mse: 0.1389
# Epoch 8/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 2.7027 - mse: 2.7027 - val_loss: 1.5110 - val_mse: 1.5110
# Epoch 9/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 1.0875 - mse: 1.0875 - val_loss: 0.4551 - val_mse: 0.4551
# Epoch 10/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.2604 - mse: 0.2604 - val_loss: 0.1468 - val_mse: 0.1468
# Epoch 11/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.1848 - mse: 0.1848 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 12/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.1868 - mse: 0.1868 - val_loss: 0.1170 - val_mse: 0.1170
# Epoch 13/100
# 8945/8945 [==============================] - 64s 7ms/step - loss: 0.1459 - mse: 0.1459 - val_loss: 0.1319 - val_mse: 0.1319
# Epoch 14/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 5.6174 - mse: 5.6174 - val_loss: 89.1920 - val_mse: 89.1920
# Epoch 15/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 4.3079 - mse: 4.3079 - val_loss: 0.6852 - val_mse: 0.6852
# Epoch 16/100
# 8945/8945 [==============================] - 66s 7ms/step - loss: 0.4059 - mse: 0.4059 - val_loss: 0.1993 - val_mse: 0.1993
# Epoch 17/100
# 8945/8945 [==============================] - 61s 7ms/step - loss: 0.2279 - mse: 0.2279 - val_loss: 0.1991 - val_mse: 0.1991
# Epoch 18/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.1887 - mse: 0.1887 - val_loss: 0.1463 - val_mse: 0.1463
# Epoch 19/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.1612 - mse: 0.1612 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 20/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.1454 - mse: 0.1454 - val_loss: 0.1532 - val_mse: 0.1532
# Epoch 21/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.1614 - mse: 0.1614 - val_loss: 0.2595 - val_mse: 0.2595
# Epoch 22/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.2855 - mse: 0.2855 - val_loss: 0.3172 - val_mse: 0.3172
# Epoch 23/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.1988 - mse: 0.1988 - val_loss: 0.1538 - val_mse: 0.1538
# Epoch 24/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.1472 - val_mse: 0.1472
# Epoch 25/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.1394 - mse: 0.1394 - val_loss: 0.0845 - val_mse: 0.0845
# Epoch 26/100
# 8945/8945 [==============================] - 66s 7ms/step - loss: 0.2678 - mse: 0.2678 - val_loss: 0.1531 - val_mse: 0.1531
# Epoch 27/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.1363 - mse: 0.1363 - val_loss: 0.1599 - val_mse: 0.1599
# Epoch 28/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.2321 - mse: 0.2321 - val_loss: 0.1082 - val_mse: 0.1082
# Epoch 29/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 3.2578 - mse: 3.2578 - val_loss: 1.3665 - val_mse: 1.3665
# Epoch 30/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 3.7352 - mse: 3.7352 - val_loss: 1.5330 - val_mse: 1.5330
# Epoch 31/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.9079 - mse: 0.9079 - val_loss: 0.4899 - val_mse: 0.4899
# Epoch 32/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.7753 - mse: 0.7753 - val_loss: 0.3990 - val_mse: 0.3990
# Epoch 33/100
# 8945/8945 [==============================] - 63s 7ms/step - loss: 0.3198 - mse: 0.3198 - val_loss: 0.1817 - val_mse: 0.1817
# Epoch 34/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.3074 - mse: 0.3074 - val_loss: 0.4109 - val_mse: 0.4109
# Epoch 35/100
# 8945/8945 [==============================] - 62s 7ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.1484 - val_mse: 0.1484
# 'Training time was 2195.5686888694763 sec'

# %%
hist = pd.DataFrame(Monitor.history)
hist['epoch'] = Monitor.epoch
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,4),dpi=150)
hist[['loss','val_loss']].plot(ax=axes[0])
hist[['mse','val_mse']].plot(ax=axes[1])
plt.show()
hist.tail()
# Out:
#         loss       mse  val_loss   val_mse  epoch
# 30  0.907875  0.907875  0.489913  0.489913     30
# 31  0.775284  0.775284  0.399027  0.399027     31
# 32  0.319766  0.319766  0.181682  0.181682     32
# 33  0.307412  0.307412  0.410860  0.410860     33
# 34  0.223311  0.223311  0.148352  0.148352     34

# %% [markdown]
# ## Evaluation

# %%
yhat = model.predict(X_test, verbose=1)
rms += [sqrt(mean_squared_error(y_test, yhat))]
print(yhat[:5])
rms
# Out:
# 3834/3834 [==============================] - 9s 2ms/step
# [[17.994724  20.422564  17.998789  20.84313  ]
#  [17.437428  38.920635  17.434309  38.92753  ]
#  [ 6.732022  19.854837   6.7397003 20.120184 ]
#  [39.02532   40.793602  39.024296  41.09278  ]
#  [ 6.717615  56.268085   6.7091722 56.342472 ]]
# [0.30731202053782647,
#  0.3152044257917025,
#  0.41217239780858556,
#  0.8317798903576169,
#  0.5861162059312589,
#  0.7522358646201334,
#  0.38516438587412954]

# %%
plt.figure(figsize=(n_labels*5,n_future*5))
k = 1
for i in range(n_future):
  for j in range(1,n_labels+1):
    plt.subplot(n_labels,n_future,k)
    plt.scatter(y_test.index,y_test.iloc[:,i], label = "true {} at t+{}".format(target_names[j-1],i),marker = 'X', )
    plt.scatter(y_test.index,yhat[:,i], label = "prediction {} at t+{}".format(target_names[j-1],i),marker = '.')
    plt.legend()
    k+=1
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Conclusion
#
# Overview on the performance of all simple models
#
# |Model name|Description| # Car|# vars|# targets|# const_vars| # steps | # futures|RMS|Computing time|
# |---|:--|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# Model 1|Baseline model with multi input time steps|1|1|1|0|**4**|1|0.307|0.1sec|
# Model 2|Add multi output time steps|1|1|1|0|4|**2**|0.315|0.1|
# Model 3|Add multi input series|1|**2**|1|0|4|2|0.412|0.1|
# Model 4|Add multi `output` series|1|2|**2**|0|4|2| 0.831|0.1|
# Model 5|Add multi constant input|1|2|2|**2**|4|2|0.586|0.1|
# Model 6|Add more objects|**4**|2|2|2|4|2|0.752|0.1
# Model 6.1|Add much more objects|**1000**|2|2|2|4|2|0.385|2200sec (37min)

# %% [markdown]
# #END
